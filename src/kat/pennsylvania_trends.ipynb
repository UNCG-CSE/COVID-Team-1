# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
c_data = pd.read_csv("../../data/Covid/covid_primary_data.csv")

# %% [markdown]
# ### The first and last values represent the part of the dataset containing values belonging to the state of Pennsylvania

# %%
first = 2280
last = 2347
c_data.loc[first:last,['cases - 9/10/20', 
                        'cases - 9/11/20','cases - 9/12/20', 
                        'cases - 9/13/20','cases - 9/14/20', 
                        'cases - 9/15/20','cases - 9/16/20']]
# Out:
#       cases - 9/10/20  cases - 9/11/20  cases - 9/12/20  cases - 9/13/20  \
# 2280                0                0                0                0
# 2281              721              723              734              734
# 2282            10969            11069            11126            11126
# 2283              370              378              380              380
# 2284             1731             1757             1767             1767
# ...               ...              ...              ...              ...
# 2343             1163             1177             1190             1190
# 2344              195              198              201              201
# 2345             1925             1945             1962             1962
# 2346               71               71               72               72
# 2347             3929             3995             4124             4124
#
#       cases - 9/14/20  cases - 9/15/20  cases - 9/16/20
# ...

# %% [markdown]
# ### There seems to be an increase in cases in the last week according to our data
